# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,100)
k = 1
plt.plot(x, np.cos(x*k), c="green")
k = 2
plt.plot(x, np.cos(x*k), c="red")
plt.show()
